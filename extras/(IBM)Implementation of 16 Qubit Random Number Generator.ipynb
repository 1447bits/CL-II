# %%
! pip install qiskit
# Out:
# Requirement already satisfied: qiskit in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (1.14.1)
# Requirement already satisfied: sympy>=1.3 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (1.13.2)
# Requirement already satisfied: dill>=0.3 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (5.3.0)
# Requirement already satisfied: typing-extensions in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from qiskit) (0.11.0)
# Requirement already satisfied: six>=1.5 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from sympy>=1.3->qiskit) (1.3.0)

# %%
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, Aer
from qiskit.execute import execute
from qiskit.visualization import circuit_drawer

# Create a quantum circuit with 16 qubits
circuit = QuantumCircuit(16, 16)

# Apply Hadamard gates to put all qubits in superposition
circuit.h(range(16))

# Measure all qubits
circuit.measure(range(16), range(16))

# Visualize the circuit
print(circuit)
circuit_drawer(circuit, output='mpl')

# Simulate the quantum circuit using the QASM simulator
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots=1)
result = job.result()
counts = result.get_counts(circuit)

# Extract the random number from the measurement outcome
random_number = list(counts.keys())[0]

# Convert the random number to binary representation
binary_number = format(int(random_number, 2), '016b')

print("Random number (decimal):", int(random_number, 2))
print("Random number (binary):", binary_number)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Importing standard Qiskit libraries
# ----> 2 from qiskit import QuantumCircuit, Aer
#       3 from qiskit.execute import execute
#       4 from qiskit.visualization import circuit_drawer
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages/qiskit/__init__.py)
